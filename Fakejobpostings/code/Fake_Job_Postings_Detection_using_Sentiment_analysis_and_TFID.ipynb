# %% [markdown]
# # <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #007fd4">Fake Job Detection using NLP</p>
#
# ##  <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:120%; text-align:left;padding: 0px;"> Goal: Detecting Fake Job Postings posted in the different job portals</p>
#
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:120%; text-align:left;padding: 0px;"> Import Libraries </p>

# %%
# !nohup python my_script.py &
# Out:
# nohup: appending output to 'nohup.out'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from bs4 import BeautifulSoup
import re
import string

from collections import Counter
from nltk.corpus import stopwords

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
from nltk.stem import WordNetLemmatizer, PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer,TfidfTransformer,CountVectorizer

from sklearn.model_selection import train_test_split

from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from nltk.corpus import opinion_lexicon
from concurrent.futures import ProcessPoolExecutor

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import MinMaxScaler

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline


from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score, classification_report,confusion_matrix,roc_curve,auc,roc_auc_score, ConfusionMatrixDisplay)

from tqdm import tqdm

import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:120%; text-align:left;padding: 0px;"> Load Data from the Source </p>

# %%
# Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_raw = pd.read_csv("/content/drive/My Drive/FAKE JOB DETECTION/DATA SET/fake_job_postings - existing.csv")
print(f"Raw Data Shape: {df_raw.shape}")
df_raw.head()
# Out:
# Raw Data Shape: (17880, 18)
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
# 3      Sales          NaN  Our passion for improving quality of life thro...
# 4        NaN          NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# 2  Our client, located in Houston, is actively se...
# 3  THE COMPANY: ESRI – Environmental Systems Rese...
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...
#
#                                         requirements  \
# 0  Experience with content management systems a m...
# 1  What we expect from you:Your key responsibilit...
# 2  Implement pre-commissioning and commissioning ...
# 3  EDUCATION: Bachelor’s or Master’s in GIS, busi...
# 4  QUALIFICATIONS:RN license in the State of Texa...
#
#                                             benefits  telecommuting  \
# 0                                                NaN              0
# 1  What you will get from usThrough being part of...              0
# 2                                                NaN              0
# 3  Our culture is anything but corporate—we have ...              0
# 4                              Full Benefits Offered              0
#
#    has_company_logo  has_questions employment_type required_experience  \
# 0                 1              0           Other          Internship
# 1                 1              0       Full-time      Not Applicable
# 2                 1              0             NaN                 NaN
# 3                 1              0       Full-time    Mid-Senior level
# 4                 1              1       Full-time    Mid-Senior level
#
#   required_education                   industry              function  \
# 0                NaN                        NaN             Marketing
# 1                NaN  Marketing and Advertising      Customer Service
# 2                NaN                        NaN                   NaN
# 3  Bachelor's Degree          Computer Software                 Sales
# 4  Bachelor's Degree     Hospital & Health Care  Health Care Provider
#
#    fraudulent
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
df = df_raw.copy()

print(f"Shape: {df.shape}")
# Out:
# Shape: (17880, 18)

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:120%; text-align:left;padding: 0px;"> Basic Data Exploration </p>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               17880 non-null  int64
#  1   title                17880 non-null  object
#  2   location             17534 non-null  object
#  3   department           6333 non-null   object
#  4   salary_range         2868 non-null   object
#  5   company_profile      14572 non-null  object
#  6   description          17879 non-null  object
#  7   requirements         15185 non-null  object
#  8   benefits             10670 non-null  object
#  9   telecommuting        17880 non-null  int64
#  10  has_company_logo     17880 non-null  int64
#  11  has_questions        17880 non-null  int64
#  12  employment_type      14409 non-null  object
#  13  required_experience  10830 non-null  object
#  14  required_education   9775 non-null   object
#  15  industry             12977 non-null  object
#  16  function             11425 non-null  object
#  17  fraudulent           17880 non-null  int64
# dtypes: int64(5), object(13)
# memory usage: 2.5+ MB

# %%
df.describe(include = "all")
# Out:
#               job_id                    title         location department  \
# count   17880.000000                    17880            17534       6333
# unique           NaN                    11231             3105       1337
# top              NaN  English Teacher Abroad   GB, LND, London      Sales
# freq             NaN                      311              718        551
# mean     8940.500000                      NaN              NaN        NaN
# std      5161.655742                      NaN              NaN        NaN
# min         1.000000                      NaN              NaN        NaN
# 25%      4470.750000                      NaN              NaN        NaN
# 50%      8940.500000                      NaN              NaN        NaN
# 75%     13410.250000                      NaN              NaN        NaN
# max     17880.000000                      NaN              NaN        NaN
#
#        salary_range                                    company_profile  \
# count          2868                                              14572
# unique          874                                               1709
# top             0-0  We help teachers get safe &amp; secure jobs ab...
# freq            142                                                726
# mean            NaN                                                NaN
# std             NaN                                                NaN
# min             NaN                                                NaN
# 25%             NaN                                                NaN
# 50%             NaN                                                NaN
# 75%             NaN                                                NaN
# max             NaN                                                NaN
#
#                                               description  \
# count                                               17879
# unique                                              14801
# top     Play with kids, get paid for it Love travel? J...
# freq                                                  379
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                              requirements  \
# count                                               15185
# unique                                              11968
# top     University degree required. TEFL / TESOL / CEL...
# freq                                                  410
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                    benefits  telecommuting  has_company_logo  has_questions  \
# count                 10670   17880.000000      17880.000000   17880.000000
# unique                 6205            NaN               NaN            NaN
# top     See job description            NaN               NaN            NaN
# freq                    726            NaN               NaN            NaN
# mean                    NaN       0.042897          0.795302       0.491723
# std                     NaN       0.202631          0.403492       0.499945
# min                     NaN       0.000000          0.000000       0.000000
# 25%                     NaN       0.000000          1.000000       0.000000
# 50%                     NaN       0.000000          1.000000       0.000000
# 75%                     NaN       0.000000          1.000000       1.000000
# max                     NaN       1.000000          1.000000       1.000000
#
#        employment_type required_experience required_education  \
# count            14409               10830               9775
# unique               5                   7                 13
# top          Full-time    Mid-Senior level  Bachelor's Degree
# freq             11620                3809               5145
# mean               NaN                 NaN                NaN
# std                NaN                 NaN                NaN
# min                NaN                 NaN                NaN
# 25%                NaN                 NaN                NaN
# 50%                NaN                 NaN                NaN
# 75%                NaN                 NaN                NaN
# max                NaN                 NaN                NaN
#
#                                    industry                function  \
# count                                 12977                   11425
# unique                                  131                      37
# top     Information Technology and Services  Information Technology
# freq                                   1734                    1749
# mean                                    NaN                     NaN
# std                                     NaN                     NaN
# min                                     NaN                     NaN
# 25%                                     NaN                     NaN
# 50%                                     NaN                     NaN
# 75%                                     NaN                     NaN
# max                                     NaN                     NaN
#
#           fraudulent
# count   17880.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        0.048434
# std         0.214688
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
df.describe(exclude="object")
# Out:
#              job_id  telecommuting  has_company_logo  has_questions  \
# count  17880.000000   17880.000000      17880.000000   17880.000000
# mean    8940.500000       0.042897          0.795302       0.491723
# std     5161.655742       0.202631          0.403492       0.499945
# min        1.000000       0.000000          0.000000       0.000000
# 25%     4470.750000       0.000000          1.000000       0.000000
# 50%     8940.500000       0.000000          1.000000       0.000000
# 75%    13410.250000       0.000000          1.000000       1.000000
# max    17880.000000       1.000000          1.000000       1.000000
#
#          fraudulent
# count  17880.000000
# mean       0.048434
# std        0.214688
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df.describe(exclude=np.number)
# Out:
#                           title         location department salary_range  \
# count                     17880            17534       6333         2868
# unique                    11231             3105       1337          874
# top     English Teacher Abroad   GB, LND, London      Sales          0-0
# freq                        311              718        551          142
#
#                                           company_profile  \
# count                                               14572
# unique                                               1709
# top     We help teachers get safe &amp; secure jobs ab...
# freq                                                  726
#
#                                               description  \
# count                                               17879
# unique                                              14801
# top     Play with kids, get paid for it Love travel? J...
# freq                                                  379
#
#                                              requirements  \
# count                                               15185
# unique                                              11968
# top     University degree required. TEFL / TESOL / CEL...
# freq                                                  410
#
#                    benefits employment_type required_experience  \
# count                 10670           14409               10830
# unique                 6205               5                   7
# top     See job description       Full-time    Mid-Senior level
# freq                    726           11620                3809
#
#        required_education                             industry  \
# count                9775                                12977
# unique                 13                                  131
# top     Bachelor's Degree  Information Technology and Services
# freq                 5145                                 1734
#
#                       function
# count                    11425
# unique                      37
# top     Information Technology
# freq                      1749

# %% [markdown]
# There are many missing feature values, we will perform futhur checks

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:120%; text-align:left;padding: 0px;">Data Checks to perform </p>
#  - Check Missing values
#  - Check Duplicates
#  - Check data type
#  - Check the number of unique values of each column
#  - Check statistics of data set
#  - Check various categories present in the different categorical column
#
#  #### Missing values

# %%
df.isnull().sum()
# Out:
# job_id                     0
# title                      0
# location                 346
# department             11547
# salary_range           15012
# company_profile         3308
# description                1
# requirements            2695
# benefits                7210
# telecommuting              0
# has_company_logo           0
# has_questions              0
# employment_type         3471
# required_experience     7050
# required_education      8105
# industry                4903
# function                6455
# fraudulent                 0
# dtype: int64

# %%
## Here we will check the percentage of nan values present in each feature
feature_na = [feature for feature in df.columns if df[feature].isnull().sum() > 0 ]

for feature in feature_na:
    print(feature, np.round(df[feature].isnull().mean() * 100,4), " % missing")
# Out:
# location 1.9351  % missing
# department 64.5805  % missing
# salary_range 83.9597  % missing
# company_profile 18.5011  % missing
# description 0.0056  % missing
# requirements 15.0727  % missing
# benefits 40.3244  % missing
# employment_type 19.4128  % missing
# required_experience 39.4295  % missing
# required_education 45.33  % missing
# industry 27.4217  % missing
# function 36.1018  % missing

# %%
# Null valuse more than 10%
columns_with_null_values_total = (df.isnull().sum() / len(df)) * 100
columns_with_null_values_percentage = columns_with_null_values_total[columns_with_null_values_total > 10].sort_values(ascending=False)

columns_with_null_values_percentage
# Out:
# salary_range           83.959732
# department             64.580537
# required_education     45.329978
# benefits               40.324385
# required_experience    39.429530
# function               36.101790
# industry               27.421700
# employment_type        19.412752
# company_profile        18.501119
# requirements           15.072707
# dtype: float64

# %% [markdown]
# <b>observation:</b> There are many missing feature values. There 8 features with ~85% values are null and 2 features with ~65% null.
#
# The feature with 50% null values can be removed from the dataset

# %%
df.drop(columns_with_null_values_percentage.keys().tolist(),axis=1,inplace=True)

df.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#                                          description  telecommuting  \
# 0  Food52, a fast-growing, James Beard Award-winn...              0
# 1  Organised - Focused - Vibrant - Awesome!Do you...              0
# 2  Our client, located in Houston, is actively se...              0
# 3  THE COMPANY: ESRI – Environmental Systems Rese...              0
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...              0
#
#    has_company_logo  has_questions  fraudulent
# 0                 1              0           0
# 1                 1              0           0
# 2                 1              0           0
# 3                 1              0           0
# 4                 1              1           0

# %%
df.columns
# Out:
# Index(['job_id', 'title', 'location', 'description', 'telecommuting',
#        'has_company_logo', 'has_questions', 'fraudulent'],
#       dtype='object')

# %%
df.drop(columns=['job_id','telecommuting','has_company_logo','has_questions'],inplace = True)

# %%
df.rename(columns={'title':'role','description':'job_description'},inplace=True)

# %%
df.head()
# Out:
#                                         role            location  \
# 0                           Marketing Intern    US, NY, New York
# 1  Customer Service - Cloud Video Production      NZ, , Auckland
# 2    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3          Account Executive - Washington DC  US, DC, Washington
# 4                        Bill Review Manager  US, FL, Fort Worth
#
#                                      job_description  fraudulent
# 0  Food52, a fast-growing, James Beard Award-winn...           0
# 1  Organised - Focused - Vibrant - Awesome!Do you...           0
# 2  Our client, located in Houston, is actively se...           0
# 3  THE COMPANY: ESRI – Environmental Systems Rese...           0
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...           0

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:120%; text-align:left;padding: 0px;"> Duplicate Values Check </p>

# %%
df.duplicated().sum()
# Out:
# 512

# %%
print("***** Duplicate check Feature wise *****\n")

# Check Job description duplications
print("job_description: ", df["job_description"].duplicated().sum())
# Out:
# ***** Duplicate check Feature wise *****
#
# job_description:  3078

# %% [markdown]
# There are duplicated records, this has to taken care during preprocessing stage

# %%
#Sorting data according to text in ascending order
sorted_data=df.sort_values('job_description', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')

sorted_data[sorted_data["job_description"].duplicated()]
# Out:
#                                                     role  \
# 14118               Experienced Dog Groomer - Costa Mesa
# 12007  EXPERIENCED CAREGIVERS NEEDED TODAY!THE BEST P...
# 11806  EXPERIENCED CAREGIVERS NEEDED TODAY!THE BEST P...
# 3030               mobile apps for Android/iOS developer
# 3951              Senior  Java Developer with Hadoop Exp
# ...                                                  ...
# 13398                         Super Marketing Specialist
# 13402                         Super Marketing Specialist
# 1823                                          Data Entry
# 9992                       Inbound Sales Representatives
# 15441                            Traffic Manager (China)
#
#                      location  \
# 14118      US, CA, Costa Mesa
# 12007         US, CO, Denver
# 11806          US, CO, denver
# 3030                 VN, 64,
# 3951           US, OH, Dublin
# ...                       ...
# 13398         CA, ON, Toronto
# 13402         CA, ON, Toronto
# 1823   US, WA, ARDENVOIR WA
# 9992      US, NY, Farmingdale
# 15441           BG, 23, Sofia
#
#                                          job_description  fraudulent
# 14118  "Pride is a personal commitment.  It is an att...           0
# 12007  "We take great care of our CarePartners so the...           0
# 11806  "We take great care of our CarePartners so the...           0
# 3030                                              #NAME?           0
# 3951                                              #NAME?           0
# ...                                                  ...         ...
# 13398  “What do you want to be when you grow up?” you...           0
# 13402  “What do you want to be when you grow up?” you...           0
# 1823   •Prepares source data for computer entry by co...           0
# 9992   •    Answering incoming calls and securing ord...           0
# 15441  ￼￼Create, maintain and adjust portfolio of ass...           0
#
# [3078 rows x 4 columns]

# %%
df.shape
# Out:
# (17880, 4)

# %% [markdown]
# #### Check the Feature Uniqueness

# %%
for feature in df.columns:
    print('{}: Unique Count: {}\n {}\n'.format(feature, len(df[feature].unique()), df[feature].unique()))
# Out:
# role: Unique Count: 11231
#  ['Marketing Intern' 'Customer Service - Cloud Video Production'
#  'Commissioning Machinery Assistant (CMA)' ...
#  'Senior Financial Analyst (Retail) ' 'Account Director - Distribution '
#  'Project Cost Control Staff Engineer - Cost Control Exp - TX']
#
# location: Unique Count: 3106
#  ['US, NY, New York' 'NZ, , Auckland' 'US, IA, Wever' ...
#  'US, CA, los Angeles' 'CA, , Ottawa' 'GB, WSX, Chichester']
#
# job_description: Unique Count: 14802
#  ['Food52, a fast-growing, James Beard Award-winning online food community and crowd-sourced and curated recipe hub, is currently interviewing full- and part-time unpaid interns to work in a small team of editors, executives, and developers in its New York City headquarters.Reproducing and/or repackaging existing Food52 content for a number of partner sites, such as Huffington Post, Yahoo, Buzzfeed, and more in their various content management systemsResearching blogs and websites for the Provisions by Food52 Affiliate ProgramAssisting in day-to-day affiliate program support, such as screening affiliates and assisting in any affiliate inquiriesSupporting with PR &amp; Events when neededHelping with office administrative work, such as filing, mailing, and preparing for meetingsWorking with developers to document bugs and suggest improvements to the siteSupporting the marketing and executive staff'
#  "Organised - Focused - Vibrant - Awesome!Do you have a passion for customer service? Slick typing skills? Maybe Account Management? ...And think administration is cooler than a polar bear on a jetski? Then we need to hear you!\xa0We are the Cloud Video Production Service and opperating on a glodal level. Yeah, it's pretty cool. Serious about\xa0delivering a world class product and excellent customer service.Our rapidly expanding business is looking for a talented Project Manager to manage the successful delivery of video projects, manage client communications and drive the production process. Work with some of the coolest brands on the planet and learn from a global team that are representing NZ is a huge way!We are entering the next growth stage of our business and growing quickly internationally. \xa0Therefore, the position is bursting with opportunity for the right person entering the business at the right time.\xa090 Seconds, the worlds Cloud Video Production Service -\xa0http://90#URL_fbe6559afac620a3cd2c22281f7b8d0eef56a73e3d9a311e2f1ca13d081dd630#90 Seconds is the worlds Cloud Video Production Service enabling brands and agencies to get high quality online video content shot and produced anywhere in the world. Fast, affordable, and all managed seamlessly in the cloud from purchase to publish.\xa090 Seconds removes the hassle, cost, risk and speed issues of working with regular video production companies by managing every aspect of video projects in a beautiful online experience. \xa0With a growing network of over 2,000 rated video professionals in over 50 countries and dedicated production success teams in 5 countries guaranteeing video project success 100%. It's as easy as commissioning a quick google adwords campaign.90 Seconds has produced almost 4,000 videos in over 30 Countries for over 500 Global brands including some of the worlds largest including Paypal, L'oreal, Sony and Barclays and has offices in Auckland, London, Sydney, Tokyo &amp; Singapore.Our Auckland office is based\xa0right in the heart of the Wynyard Quarter Innovation Precinct - GridAKL!\xa0"
#  'Our client, located in Houston, is actively seeking an experienced Commissioning Machinery Assistant that possesses strong supervisory skills and has an attention to detail. A strong dedication to safety is a must. The ideal candidate will execute all activities while complying with quality requirements and health, environmental, and safety regulations.'
#  ...
#  'The Payroll Accountant will focus primarily on payroll functions for approximately 100 (and counting!) employees. In addition, this individual will assist with various tasks within the accounting department of a rapidly growing, cutting edge web development company.The ideal candidate would be\xa0well-versed in payroll\xa0and possess the experience and autonomy to be able to work with minimal supervision while fulfilling all obligations in a\xa0fun, open work environment.\xa0Candidate must also possess\xa0expertise in application of accounting principles and practices\xa0to\xa0provide support for the Accounting Team.Responsibilities:- Process semi-monthly payroll through outsourced payroll service- Handle all accounting, analysis and administrative functions relating to payroll- Resolve and respond timely to payroll-related inquiries and issues- Benefits Administration, including point of contact for third party vendors- Complete payroll general account analysis and journal entries- Perform internal payroll reviews to ensure accuracy and compliance- Maintain employee personnel files- Co-ordinate annual renewals for flexible spending and transit reimbursement programs- Assist the Accounting Team with Accounts Payable \xa0'
#  'Experienced Project Cost Control Staff Engineer is required having responsibility to provide proper variance explanation and root causes analysis of changes\xa0D - 166Job Responsibilities:\xa0Cost Control for large capital investments of various size and complexityActive participation in the overall cost control process.\xa0Ensure proper progress tracking and change management systems are in place and effectively functioning in construction and detailed engineering phases of projects.Provide proper variance explanation and root causes analysis of changesDevelopment of project cost forecast and preparation of project cost reportsAssist in the development and improvement of cost controlling tools and processes.Strong analytical skills that will allow proper assessments of projects to identify potential issues.\xa0Able support development and recommend solutions via communication and support with Project Management.Perform studies and analysisPerform bid analysis for complex service contractsPerform audits of invoicesEvaluate field change orders and validate contractor estimate and pricingDevelopment and support of contracting strategy for large capital projectsWill be required to work both independently and with a team in carrying out a project’s cost control and forecasting\xa0 efforts\xa0'
#  'Nemsia Studios is looking for an experienced visual/graphic designer to join our Lagos office. The idealcandidate will be versatile in both print and digital design mediums. Working closely with our Strategists and creative team you will be engaged on projects from the pitch phase through brainstorming, concepting, and design to execution and final delivery. You will bring your all to\xa0creating and crafting BEAUTIFUL visual expressions of ideas and briefs. We will always have ongoing internal projects.']
#
# fraudulent: Unique Count: 2
#  [0 1]

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:120%; text-align:left;padding: 0px;"> Data preprocessing </p>
#
# <b>Handle Missing Values</b>

# %%
df.isnull().sum()
# Out:
# role                 0
# location           346
# job_description      1
# fraudulent           0
# dtype: int64

# %%
# Fill na values with missing

for feature in df.columns:
  if(df[feature].isnull().sum()>0):
    df[feature].fillna("missing", inplace=True)

df.isnull().sum()
# Out:
# role               0
# location           0
# job_description    0
# fraudulent         0
# dtype: int64

# %% [markdown]
# <b>Deduplication of data</b>

# %%
df.duplicated().sum()
# Out:
# 512

# %%
df.drop_duplicates(keep="first", inplace= True)
print("Shape: ", df.shape)

df.duplicated().sum()
# Out:
# Shape:  (17368, 4)
# 0

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:120%; text-align:left;padding: 0px;"> Exploratory Data Analysis </p>
#
# #### Description: Analyze the count of Charecters, Words, and Sentences in each segment

# %%
 # Checking for distribution of class label(percentages belonging to real class and percentages belonging to fraud class)
 # in the data 1 indicates fraud post
 # 0 indicating real post
 # Plotting pie chart for the data
 # function of Explode function: how the portion will appear (to understand change explode=(0,0.5))

labels = 'Fake', 'Real'
sizes = [df.fraudulent[df['fraudulent']== 1].count(), df.fraudulent[df['fraudulent']== 0].count()]
explode = (0, 0.1)
fig1, ax1 = plt.subplots(figsize=(8, 6)) #size of the pie chart
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%',
        shadow=True, startangle=120) #autopct %1.2f%% for 2 digit precision
ax1.axis('equal')
plt.title("Proportion of Fraudulent", size = 7)
plt.show()

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# No. of charecters in Job Description
df['desc_num_char'] = df['job_description'].apply(len)

# No. of of words in Job Description
df['desc_num_words'] = df['job_description'].apply(lambda x:len(nltk.word_tokenize(x)))

# No. of of sentences in Job Description
df['desc_num_sent'] = df['job_description'].apply(lambda x:len(nltk.sent_tokenize(x)))

df.head()
# Out:
#                                         role            location  \
# 0                           Marketing Intern    US, NY, New York
# 1  Customer Service - Cloud Video Production      NZ, , Auckland
# 2    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3          Account Executive - Washington DC  US, DC, Washington
# 4                        Bill Review Manager  US, FL, Fort Worth
#
#                                      job_description  fraudulent  \
# 0  Food52, a fast-growing, James Beard Award-winn...           0
# 1  Organised - Focused - Vibrant - Awesome!Do you...           0
# 2  Our client, located in Houston, is actively se...           0
# 3  THE COMPANY: ESRI – Environmental Systems Rese...           0
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...           0
#
#    desc_num_char  desc_num_words  desc_num_sent
# 0            905             139              1
# 1           2077             359             15
# 2            355              57              3
# 3           2600             384              6
# 4           1520             203              2

# %%
df.describe(include=np.number)
# Out:
#          fraudulent  desc_num_char  desc_num_words  desc_num_sent
# count  17368.000000   17368.000000    17368.000000   17368.000000
# mean       0.046983    1212.639855      193.615154       5.159489
# std        0.211608     894.430544      140.779922       4.317656
# min        0.000000       6.000000        0.000000       0.000000
# 25%        0.000000     601.000000       97.000000       2.000000
# 50%        0.000000    1011.000000      164.000000       4.000000
# 75%        0.000000    1581.000000      253.000000       7.000000
# max        1.000000   14907.000000     2448.000000      85.000000

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:120%; text-align:left;padding: 0px;"> Text preprocessing </p>
#
# Now that we have finished deduplication our data requires some preprocessing before we go on further with analysis and making the prediction model.
#
# Hence in the Preprocessing phase we do the following in the order below:-
#
# 1. Begin by removing the html tags
# 2. Remove any punctuations or limited set of special characters like , or . or # etc.
# 3. Check if the word is made up of english letters and is not alpha-numeric
# 4. Check to see if the length of the word is greater than 2 (as it was researched that there is no adjective in 2-letters)
# 5. Convert the word to lowercase
# 6. Remove Stopwords
# 7. Finally Snowball Stemming the word (it was obsereved to be better than Porter Stemming)<br>
#
# After which we collect the words used to describe positive and negative type

# %%
# https://gist.github.com/sebleier/554280
# we are removing the words from the stop words list: 'no', 'nor', 'not'
# <br /><br /> ==> after the above steps, we are getting "br br"
# we are including them into stop words list
# instead of <br /> if we have <br/> these tags would have revmoved in the 1st step

stopWords= set(['br', 'the', 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've",\
            "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', \
            'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their',\
            'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', \
            'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', \
            'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', \
            'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after',\
            'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further',\
            'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',\
            'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', \
            's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', \
            've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn',\
            "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn',\
            "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", \
            'won', "won't", 'wouldn', "wouldn't"])

# %%
def decontracted(phrase):
    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

def preprocess(corpus):
    preprocessed = []
    for sentance in tqdm(corpus):
        #sentance = re.sub(r"http+", "", sentance)
        sentance = re.sub(r"http\S+", "", sentance)
        sentance = BeautifulSoup(sentance, 'lxml').get_text()
        sentance = decontracted(sentance)
        sentance = re.sub("\S*\d\S*", "", sentance).strip()
        sentance = re.sub('[^A-Za-z]+', ' ', sentance)
        #sentance = ' '.join(e.lower() for e in sentance.split() if e.lower() not in stopWords)
        #sentence = ' '.join(token.lower() for token in nltk.word_tokenize(sentance) if token.lower() not in stopwords.words('english'))
        #preprocessed.append(sentance.strip())
        preprocessed.append(' '.join(token.lower() for token in nltk.word_tokenize(sentance) if token.lower() not in stopwords.words('english')))

    return preprocessed

# %%
df.sample(5)
# Out:
#                                   role             location  \
# 8677    Project Subcontracting Manager      US, TX, Houston
# 5377                 Product Sourcing   US, CA, Chula Vista
# 15678  Factory - Production Assemblers               NZ, ,
# 12347             iOS Developer Intern  US, FL, Gainesville
# 12592                        HR Intern      GB, LND, London
#
#                                          job_description  fraudulent  \
# 8677   Corporate overviewAker Solutions is a global p...           1
# 5377   QB Medical, Inc. is a growing medical supply d...           0
# 15678  Great role for someone looking for part-time/f...           0
# 12347  MyTime Apps is seeking motivated interns that ...           0
# 12592  About us:Wedo is a curated collection of niche...           0
#
#        desc_num_char  desc_num_words  desc_num_sent
# 8677            4289             650              9
# 5377             929             130              4
# 15678            589             104              1
# 12347            435              75              3
# 12592           1175             216              7

# %%
df.dtypes
# Out:
# role               object
# location           object
# job_description    object
# fraudulent          int64
# desc_num_char       int64
# desc_num_words      int64
# desc_num_sent       int64
# dtype: object

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# %%time

df["desc_transformed"] = preprocess(df['job_description'].values)
#df["site_transformed"] = preprocess(df['site'].values)
#df["role_transformed"] = preprocess(df['role'].values)
#df["comp_transformed"] = preprocess(df['company_name'].values)
#df["loc_transformed"] = preprocess(df['location'].values)


df["desc_transformed"][:5]
# Out:
# 100%|██████████| 17368/17368 [04:01<00:00, 72.03it/s]
# CPU times: user 3min 26s, sys: 30.8 s, total: 3min 56s
# Wall time: 4min 1s
# 0    fast growing james beard award winning online ...
# 1    organised focused vibrant awesome passion cust...
# 2    client located houston actively seeking experi...
# 3    company esri environmental systems research in...
# 4    job title itemization review managerlocation f...
# Name: desc_transformed, dtype: object

# %%
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
# we will plot 3 kind of word cloud
# 1st we will visualize all the words our data using the wordcloud plot
# 2nd we will visualize common words in real job posting
# 3rd we will visualize common words in fraud job posting
# join function is a core python function

# %%
# Extract the text from DataFrame
desc_text_data = df['desc_transformed'].str.cat(sep=" ")

# Generate the word cloud
wc = WordCloud()
desc_post = wc.generate(desc_text_data)

# Plot the word cloud
plt.figure(figsize=(13, 8))
plt.imshow(desc_post)
plt.show()

# %%
# Extract the real post text from DataFrame
real_post_text_data = df[df['fraudulent']==0]['desc_transformed'].str.cat(sep=" ")

# Generate the word cloud
wc = WordCloud()
real_post = wc.generate(real_post_text_data)

# Plot the word cloud
plt.figure(figsize=(13, 8))
plt.imshow(real_post)
plt.show()

# %%
# Extract the fraud post text from DataFrame
fraud_post_text_data = df[df['fraudulent']==1]['desc_transformed'].str.cat(sep=" ")

# Generate the word cloud
wc = WordCloud()
fraud_post = wc.generate(fraud_post_text_data)

# Plot the word cloud
plt.figure(figsize=(13, 8))
plt.imshow(fraud_post)
plt.show()

# %%
df.fraudulent.value_counts()
# Out:
# 0    16552
# 1      816
# Name: fraudulent, dtype: int64

# %% [markdown]
# <b>Extract the Opinin from the Lexicon Lib</b>

# %%
# Download the lexicon
nltk.download('opinion_lexicon')
# Out:
# [nltk_data] Downloading package opinion_lexicon to /root/nltk_data...
# [nltk_data]   Unzipping corpora/opinion_lexicon.zip.
# True

# %%
# Get positive and negative words from the lexicon
positive_words = set(opinion_lexicon.positive())
negative_words = set(opinion_lexicon.negative())

# %%
# Positive and negative word count for desc
# Tokenize your desc_text_data
tokens = word_tokenize(desc_text_data)

# Calculate sentiment score
positive_score = sum(word in positive_words for word in tokens)
negative_score = sum(word in negative_words for word in tokens)

# Print the sentiment scores
print("Positive Score:", positive_score)
print("Negative Score:", negative_score)
# Out:
# Positive Score: 168141
# Negative Score: 23687

# %%
# Positive and negative word count for real_post
# Tokenize your real_post_text_data
tokens = word_tokenize(real_post_text_data)

# Calculate sentiment score
positive_score = sum(word in positive_words for word in tokens)
negative_score = sum(word in negative_words for word in tokens)

# Print the sentiment scores
print("Positive Score:", positive_score)
print("Negative Score:", negative_score)
# Out:
# Positive Score: 161376
# Negative Score: 22668

# %%
# Positive and negative word count for fraud_post
# Tokenize your fraud_post_text_data
tokens = word_tokenize(fraud_post_text_data)

# Calculate sentiment score
positive_score = sum(word in positive_words for word in tokens)
negative_score = sum(word in negative_words for word in tokens)

# Print the sentiment scores
print("Positive Score:", positive_score)
print("Negative Score:", negative_score)
# Out:
# Positive Score: 6765
# Negative Score: 1019

# %%
# %%time
#OPTIMIZED
# Assuming you have a DataFrame named df with a column 'desc_transformed'
data_for_parallel = df[['desc_transformed']].copy()


# Function to calculate sentiment scores for a single row
def calculate_sentiment_scores(row):
    tokens = word_tokenize(row['desc_transformed'])
    positive_score = np.sum(np.isin(tokens, list(positive_words)))
    negative_score = np.sum(np.isin(tokens, list(negative_words)))
    return positive_score, negative_score

# Convert Pandas DataFrame to a list of dictionaries
data_for_parallel = data_for_parallel.to_dict('records')

# Calculate sentiment scores using GPU and parallelization
with ProcessPoolExecutor() as executor:
    sentiment_scores = list(executor.map(calculate_sentiment_scores, data_for_parallel))

# Assign sentiment scores to the DataFrame
df[['positive_score', 'negative_score']] = np.array(sentiment_scores)

# Display the DataFrame with new sentiment score columns
print(df[['desc_transformed', 'positive_score', 'negative_score']])
# Out:
#                                         desc_transformed  positive_score  \
# 0      fast growing james beard award winning online ...               7
# 1      organised focused vibrant awesome passion cust...              22
# 2      client located houston actively seeking experi...               3
# 3      company esri environmental systems research in...              19
# 4      job title itemization review managerlocation f...               5
# ...                                                  ...             ...
# 17875  case first time visited website vend award win...              15
# 17876  payroll accountant focus primarily payroll fun...               9
# 17877  experienced project cost control staff enginee...              13
# 17878  nemsia studios looking experienced visual grap...               3
# 17879  vend award winning web based point sale softwa...              24
#
#        negative_score
# 0                   1
# 1                   7
# 2                   0
# 3                   3
# 4                   4
# ...               ...
# 17875               1
# 17876               1
# 17877               2
# 17878               0
# 17879               6
#
# [17368 rows x 3 columns]
# CPU times: user 5.24 s, sys: 1.19 s, total: 6.42 s
# Wall time: 50.1 s

# %%
df.head()
# Out:
#                                         role            location  \
# 0                           Marketing Intern    US, NY, New York
# 1  Customer Service - Cloud Video Production      NZ, , Auckland
# 2    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3          Account Executive - Washington DC  US, DC, Washington
# 4                        Bill Review Manager  US, FL, Fort Worth
#
#                                      job_description  fraudulent  \
# 0  Food52, a fast-growing, James Beard Award-winn...           0
# 1  Organised - Focused - Vibrant - Awesome!Do you...           0
# 2  Our client, located in Houston, is actively se...           0
# 3  THE COMPANY: ESRI – Environmental Systems Rese...           0
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...           0
#
#    desc_num_char  desc_num_words  desc_num_sent  \
# 0            905             139              1
# 1           2077             359             15
# 2            355              57              3
# 3           2600             384              6
# 4           1520             203              2
#
#                                     desc_transformed  positive_score  \
# 0  fast growing james beard award winning online ...               7
# 1  organised focused vibrant awesome passion cust...              22
# 2  client located houston actively seeking experi...               3
# 3  company esri environmental systems research in...              19
# 4  job title itemization review managerlocation f...               5
#
#    negative_score
# 0               1
# 1               7
# 2               0
# 3               3
# 4               4

# %%
df_score=df.copy()

# %%
df_score.to_csv("/content/drive/My Drive/FAKE JOB DETECTION/DATA SET/Existing_data_score.csv", index=False)

# %%
df = pd.read_csv("/content/drive/My Drive/FAKE JOB DETECTION/DATA SET/Existing_data_score.csv")

# %%
df.head()
# Out:
#                                         role            location  \
# 0                           Marketing Intern    US, NY, New York
# 1  Customer Service - Cloud Video Production      NZ, , Auckland
# 2    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3          Account Executive - Washington DC  US, DC, Washington
# 4                        Bill Review Manager  US, FL, Fort Worth
#
#                                      job_description  fraudulent  \
# 0  Food52, a fast-growing, James Beard Award-winn...           0
# 1  Organised - Focused - Vibrant - Awesome!Do you...           0
# 2  Our client, located in Houston, is actively se...           0
# 3  THE COMPANY: ESRI – Environmental Systems Rese...           0
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...           0
#
#    desc_num_char  desc_num_words  desc_num_sent  \
# 0            905             139              1
# 1           2077             359             15
# 2            355              57              3
# 3           2600             384              6
# 4           1520             203              2
#
#                                     desc_transformed  positive_score  \
# 0  fast growing james beard award winning online ...               7
# 1  organised focused vibrant awesome passion cust...              22
# 2  client located houston actively seeking experi...               3
# 3  company esri environmental systems research in...              19
# 4  job title itemization review managerlocation f...               5
#
#    negative_score
# 0               1
# 1               7
# 2               0
# 3               3
# 4               4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17368 entries, 0 to 17367
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   role              17368 non-null  object
#  1   location          17368 non-null  object
#  2   job_description   17368 non-null  object
#  3   fraudulent        17368 non-null  int64
#  4   desc_num_char     17368 non-null  int64
#  5   desc_num_words    17368 non-null  int64
#  6   desc_num_sent     17368 non-null  int64
#  7   desc_transformed  17367 non-null  object
#  8   positive_score    17368 non-null  int64
#  9   negative_score    17368 non-null  int64
# dtypes: int64(6), object(4)
# memory usage: 1.3+ MB

# %%
# Fill missing value in 'desc_transformed' with an empty string
df['desc_transformed'].fillna('', inplace=True)

# %%
# Assuming you have a DataFrame 'df' with 'desc_transformed' as text, 'fraudulent' as label,
# 'positive_score', 'negative_score', and other potential features

# Extract features and labels
X_text = df['desc_transformed']
X_numeric = df[['positive_score', 'negative_score', 'desc_num_char', 'desc_num_words', 'desc_num_sent']]  # Add other features as needed
y = df['fraudulent']

# Split the data
X_text_train, X_text_test, X_numeric_train, X_numeric_test, y_train, y_test = train_test_split(
    X_text, X_numeric, y, test_size=0.2, random_state=42
)

# TF-IDF vectorization for text data
tfidf_vectorizer = TfidfVectorizer(max_features=5000)
X_text_train_tfidf = tfidf_vectorizer.fit_transform(X_text_train)
X_text_test_tfidf = tfidf_vectorizer.transform(X_text_test)

# Combine text TF-IDF vectors with numeric features
X_train_combined = pd.concat([
    X_numeric_train.reset_index(drop=True),
    pd.DataFrame(X_text_train_tfidf.toarray())
], axis=1)

X_test_combined = pd.concat([
    X_numeric_test.reset_index(drop=True),
    pd.DataFrame(X_text_test_tfidf.toarray())
], axis=1)


# Standardize numeric features
scaler = StandardScaler()
X_train_combined.iloc[:, :5] = scaler.fit_transform(X_train_combined.iloc[:, :5])
X_test_combined.iloc[:, :5] = scaler.transform(X_test_combined.iloc[:, :5])

# Identify numeric columns
numeric_columns = ['positive_score', 'negative_score', 'desc_num_char', 'desc_num_words', 'desc_num_sent']

# Apply Min-Max scaling to numeric features
min_max_scaler = MinMaxScaler()
X_train_combined[numeric_columns] = min_max_scaler.fit_transform(X_train_combined[numeric_columns])
X_test_combined[numeric_columns] = min_max_scaler.transform(X_test_combined[numeric_columns])

# %%
# Convert feature names to strings
X_train_combined.columns = X_train_combined.columns.astype(str)

# Apply SMOTE to balance the training data
smote = SMOTE(random_state=42)
X_train_combined, y_train = smote.fit_resample(X_train_combined, y_train)

# %%
print(f"{X_train_combined.shape}")
print(f"{y_train.shape}")
# Out:
# (26460, 5005)
# (26460,)

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:120%; text-align:left;padding: 0px;">Model Building </p>

# %%
modelName = []
trainaccScore = []
testaccScore = []
aucrocScore = []
precScore = []
recallScore = []
X_train_combined.columns = X_train_combined.columns.astype(str)
X_test_combined.columns = X_test_combined.columns.astype(str)

def computePerformance(X_train_combined, X_test_combined, y_train, y_test, model, modelname):

    train_pred = model.predict(X_train_combined)
    y_pred = model.predict(X_test_combined)

    # Training test Accuracy
    accuracy_train = accuracy_score(y_train,train_pred)
    print("Train Accuracy:", accuracy_train)

    # Test test Accuracy
    accuracy_test = accuracy_score(y_test,y_pred)
    print("Test Accuracy:", accuracy_test)

    # Precision Score
    precisionScore = precision_score(y_test,y_pred)
    print("Precision Score:", precisionScore)

    # Recall Score
    recScore = recall_score(y_test,y_pred)
    print("Recall Score:", recScore)

    # F1 Score
    f1Score = f1_score(y_test,y_pred)
    print("F1 Score:", f1Score)


    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    print("\n****** Confusion Matrix *****")
    print(cm)

    # Classification report
    print("\n****** Classification Report *****")
    report = classification_report(y_test, y_pred, target_names=["Fake","Real"])
    print(report)


    # AUC ROC Curve
    preds = model.predict_proba(X_test_combined)[:,1]
    rocaucScore = roc_auc_score(y_test, preds)
    print("\n AUC_ROC Score:", rocaucScore)

    modelName.append(modelname)
    trainaccScore.append(accuracy_train)
    testaccScore.append(accuracy_test)
    aucrocScore.append(rocaucScore)
    precScore.append(precisionScore)
    recallScore.append(recScore)

# %% [markdown]
# #### Base Models
# <b>Gaussian NB</b>

# %%
model_gNB =  GaussianNB()
model_gNB.fit(X_train_combined, y_train)

computePerformance(X_train_combined, X_test_combined, y_train, y_test, model_gNB,"GaussianNB")
# Out:
# Train Accuracy: 0.9667044595616024
# Test Accuracy: 0.918825561312608
# Precision Score: 0.3018292682926829
# Recall Score: 0.6513157894736842
# F1 Score: 0.4125
#
# ****** Confusion Matrix *****
# [[3093  229]
#  [  53   99]]
#
# ****** Classification Report *****
#               precision    recall  f1-score   support
#
#         Fake       0.98      0.93      0.96      3322
#         Real       0.30      0.65      0.41       152
#
#     accuracy                           0.92      3474
#    macro avg       0.64      0.79      0.68      3474
# weighted avg       0.95      0.92      0.93      3474
#
#
#  AUC_ROC Score: 0.7908233388256914

# %% [markdown]
# #### LogisticRegression

# %%
# Logistic Regression model
model_lr = LogisticRegression()
model_lr.fit(X_train_combined, y_train)

# Predictions
predictions = model_lr.predict(X_test_combined)

# Evaluate
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy}")
print(classification_report(y_test, predictions))
computePerformance(X_train_combined, X_test_combined, y_train, y_test, model_lr,"LogisticRegression")
# Out:
# Accuracy: 0.9438687392055267
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97      3322
#            1       0.42      0.76      0.54       152
#
#     accuracy                           0.94      3474
#    macro avg       0.70      0.85      0.76      3474
# weighted avg       0.96      0.94      0.95      3474
#
# Train Accuracy: 0.9824263038548753
# Test Accuracy: 0.9438687392055267
# Precision Score: 0.42124542124542125
# Recall Score: 0.756578947368421
# F1 Score: 0.5411764705882353
#
# ****** Confusion Matrix *****
# [[3164  158]
#  [  37  115]]
#
# ****** Classification Report *****
#               precision    recall  f1-score   support
#
#         Fake       0.99      0.95      0.97      3322
#         Real       0.42      0.76      0.54       152
#
#     accuracy                           0.94      3474
#    macro avg       0.70      0.85      0.76      3474
# weighted avg       0.96      0.94      0.95      3474
#
#
#  AUC_ROC Score: 0.9348601032985835

# %%
knc = KNeighborsClassifier()
gNB =  GaussianNB()
mnb = MultinomialNB()
bnb =  BernoulliNB()
lrc = LogisticRegression(solver='liblinear', penalty='l1')
dtc = DecisionTreeClassifier(max_depth=5)
svc = SVC(kernel='sigmoid', gamma=1.0)
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

clfs = {
    'KN' : knc,
    'gNB': gNB,
    'mNB': mnb,
    'bNB': bnb,
    'LR': lrc,
    'SVC' : svc,
    'DT': dtc,
    'RF': rfc,
    'BgC': bc,
    'ETC': etc,
    'GBDT':gbdt,
    'xgb':xgb,
    'AdaBoost': abc
}

# %%
def train_classifier(clf,X_train_combined,y_train,X_test_combined,y_test):
    clf.fit(X_train_combined,y_train)
    y_pred = clf.predict(X_test_combined)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    recall = recall_score(y_test,y_pred)
    f1score = f1_score(y_test,y_pred,average='weighted')

    return accuracy,precision,recall,f1score

# %%
print(X_train_combined[X_train_combined < 0].sum())
# Out:
# positive_score    0.0
# negative_score    0.0
# desc_num_char     0.0
# desc_num_words    0.0
# desc_num_sent     0.0
#                  ...
# 4995              0.0
# 4996              0.0
# 4997              0.0
# 4998              0.0
# 4999              0.0
# Length: 5005, dtype: float64

# %%
# %%time
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

for name,clf in clfs.items():

    current_accuracy,current_precision,current_recall,current_f1score = train_classifier(clf, X_train_combined, y_train,X_test_combined,y_test)

    print(f"{name} Accuracy: {current_accuracy} Precision: {current_precision} Recall: {current_recall} F1Score: {current_f1score}")

    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
    recall_scores.append(current_recall)
    f1_scores.append(current_f1score)
# Out:
# KN Accuracy: 0.41508347725964306 Precision: 0.0692025664527956 Recall: 0.993421052631579 F1Score: 0.5407779952411054
# gNB Accuracy: 0.918825561312608 Precision: 0.3018292682926829 Recall: 0.6513157894736842 F1Score: 0.9326031276068286
# mNB Accuracy: 0.9052964881980426 Precision: 0.2846715328467153 Recall: 0.7697368421052632 F1Score: 0.9251592098632393
# bNB Accuracy: 0.9191134139320668 Precision: 0.2736842105263158 Recall: 0.5131578947368421 F1Score: 0.9305961083236195
# LR Accuracy: 0.9418537708693149 Precision: 0.40384615384615385 Recall: 0.6907894736842105 F1Score: 0.9489944782690343
# SVC Accuracy: 0.9245826137017847 Precision: 0.33433734939759036 Recall: 0.7302631578947368 F1Score: 0.9375564514176336
# DT Accuracy: 0.7976396085204376 Precision: 0.11360448807854137 Recall: 0.5328947368421053 F1Score: 0.8539292558040491
# RF Accuracy: 0.9792746113989638 Precision: 0.9761904761904762 Recall: 0.5394736842105263 F1Score: 0.9763937359092447
# BgC Accuracy: 0.9726540011514104 Precision: 0.7394957983193278 Recall: 0.5789473684210527 F1Score: 0.9710565999651514
# ETC Accuracy: 0.9798503166378814 Precision: 0.9767441860465116 Recall: 0.5526315789473685 F1Score: 0.9771555497818483
# GBDT Accuracy: 0.9205526770293609 Precision: 0.30254777070063693 Recall: 0.625 F1Score: 0.9333694051276074
# xgb Accuracy: 0.9726540011514104 Precision: 0.7435897435897436 Recall: 0.5723684210526315 F1Score: 0.970946637049623
# AdaBoost Accuracy: 0.8888888888888888 Precision: 0.22142857142857142 Recall: 0.6118421052631579 F1Score: 0.9125832692332064
# CPU times: user 27min 18s, sys: 3.15 s, total: 27min 21s
# Wall time: 26min 29s

# %%
modelScore = pd.DataFrame({'Model':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores,
                               'Recall':recall_scores,'F1Score':f1_scores}
                             ).sort_values(['F1Score','Precision','Recall'],ascending=False)

modelScore
# Out:
#        Model  Accuracy  Precision    Recall   F1Score
# 9        ETC  0.979850   0.976744  0.552632  0.977156
# 7         RF  0.979275   0.976190  0.539474  0.976394
# 8        BgC  0.972654   0.739496  0.578947  0.971057
# 11       xgb  0.972654   0.743590  0.572368  0.970947
# 4         LR  0.941854   0.403846  0.690789  0.948994
# 5        SVC  0.924583   0.334337  0.730263  0.937556
# 10      GBDT  0.920553   0.302548  0.625000  0.933369
# 1        gNB  0.918826   0.301829  0.651316  0.932603
# 3        bNB  0.919113   0.273684  0.513158  0.930596
# 2        mNB  0.905296   0.284672  0.769737  0.925159
# 12  AdaBoost  0.888889   0.221429  0.611842  0.912583
# 6         DT  0.797640   0.113604  0.532895  0.853929
# 0         KN  0.415083   0.069203  0.993421  0.540778

# %%
best_model = modelScore.iloc[0]
print("Best Performing Model:")
print(best_model)
# Out:
# Best Performing Model:
# Model             ETC
# Accuracy      0.97985
# Precision    0.976744
# Recall       0.552632
# F1Score      0.977156
# Name: 9, dtype: object

# %%
best_model_name = modelScore.iloc[0]['Model']

# Instantiate the best-performing model based on its name
best_model = clfs[best_model_name]

print("Best Performing Model:")
print(best_model_name)

# Assuming X_train_combined, X_test_combined, y_train, and y_test are defined
computePerformance(X_train_combined, X_test_combined, y_train, y_test, best_model, best_model_name)
# Out:
# Best Performing Model:
# ETC
# Train Accuracy: 1.0
# Test Accuracy: 0.9798503166378814
# Precision Score: 0.9767441860465116
# Recall Score: 0.5526315789473685
# F1 Score: 0.7058823529411765
#
# ****** Confusion Matrix *****
# [[3320    2]
#  [  68   84]]
#
# ****** Classification Report *****
#               precision    recall  f1-score   support
#
#         Fake       0.98      1.00      0.99      3322
#         Real       0.98      0.55      0.71       152
#
#     accuracy                           0.98      3474
#    macro avg       0.98      0.78      0.85      3474
# weighted avg       0.98      0.98      0.98      3474
#
#
#  AUC_ROC Score: 0.9539057796508128

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Assuming y_test and predicted probabilities (probas) are available
y_proba = best_model.predict_proba(X_test_combined)[:, 1]

# Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# <b>Fraudulent wise WordCloud</b>

# %%
fraud_corpus = []
for msg in df[df['fraudulent'] == 1]['desc_transformed'].tolist():
    for word in msg.split():
        fraud_corpus.append(word)

len(fraud_corpus)
# Out:
# 82839

# %%
real_corpus = []
for msg in df[df['fraudulent'] == 0]['desc_transformed'].tolist():
    for word in msg.split():
        real_corpus.append(word)

len(real_corpus)
# Out:
# 1798641

# %% [markdown]
# <b>Fake - 30 Most used words</b>

# %%
sns.barplot(x = pd.DataFrame(Counter(fraud_corpus).most_common(30))[0],
            y = pd.DataFrame(Counter(fraud_corpus).most_common(30))[1]
           )
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# <b>Real - 30 Most used words</b>

# %%
sns.barplot(x = pd.DataFrame(Counter(real_corpus).most_common(30))[0],
            y = pd.DataFrame(Counter(real_corpus).most_common(30))[1]
           )
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:120%; text-align:left;padding: 0px;">Featurization </p>
#
# <b>BOW - Bag of words</b>
# Count Vectorization: This is a simpler vectorization technique which relies on frequency of occurence of a particular term in a document or corpus.

# %%
preprocessed_desc = df["desc_transformed"]

# %%
# %%time
##BoW
count_vect = CountVectorizer()
count_vect.fit(preprocessed_desc)

print("some feature names ", count_vect.get_feature_names_out()[:10])
print('='*50)

final_counts = count_vect.transform(preprocessed_desc)

print("the type of count vectorizer ",type(final_counts))
print("the shape of out text BOW vectorizer ",final_counts.get_shape())
print("the number of unique words ", final_counts.get_shape()[1])
# Out:
# some feature names  ['aa' 'aaa' 'aaahc' 'aac' 'aachen' 'aae' 'aaes' 'aafes' 'aalto' 'aan']
# ==================================================
# the type of count vectorizer  <class 'scipy.sparse._csr.csr_matrix'>
# the shape of out text BOW vectorizer  (17368, 56392)
# the number of unique words  56392
# CPU times: user 2.97 s, sys: 17.8 ms, total: 2.99 s
# Wall time: 3.04 s

# %% [markdown]
# <b>Bi-Grams and n-Grams</b>

# %%
# %%time
#bi-gram, tri-gram and n-gram


count_vect = CountVectorizer(ngram_range=(1,2), min_df=10, max_features=5000)
final_bigram_counts = count_vect.fit_transform(preprocessed_desc)

print("the type of count vectorizer ",type(final_bigram_counts))
print("the shape of out text BOW vectorizer ",final_bigram_counts.get_shape())
print("the number of unique words including both unigrams and bigrams ", final_bigram_counts.get_shape()[1])
# Out:
# the type of count vectorizer  <class 'scipy.sparse._csr.csr_matrix'>
# the shape of out text BOW vectorizer  (17368, 5000)
# the number of unique words including both unigrams and bigrams  5000
# CPU times: user 4.61 s, sys: 163 ms, total: 4.78 s
# Wall time: 4.78 s

# %% [markdown]
# <b>TF-IDF</b><br/>
#
# TF-IDF Vectorization: This works by applying a logarithmic term to inverse document frequency (IDF) part other than determining the "TF" or term freqency part

# %%
# %%time

tf_idf_vect = TfidfVectorizer(ngram_range=(1,3), max_features=3000)
tf_idf_vect.fit(preprocessed_desc)

print("some sample features(unique words in the corpus)",tf_idf_vect.get_feature_names_out()[0:10])
print('='*50)

final_tf_idf = tf_idf_vect.transform(preprocessed_desc)

print("the type of count vectorizer ",type(final_tf_idf))
print("the shape of out text TFIDF vectorizer ",final_tf_idf.get_shape())
print("the number of unique words including both unigrams and bigrams ", final_tf_idf.get_shape()[1])
# Out:
# some sample features(unique words in the corpus) ['abilities' 'ability' 'ability communicate' 'ability work' 'able'
#  'able work' 'abroad' 'academic' 'accept' 'access']
# ==================================================
# the type of count vectorizer  <class 'scipy.sparse._csr.csr_matrix'>
# the shape of out text TFIDF vectorizer  (17368, 3000)
# the number of unique words including both unigrams and bigrams  3000
# CPU times: user 15.7 s, sys: 453 ms, total: 16.2 s
# Wall time: 16.6 s

# %%
print("TF_IDF Shape: ", final_tf_idf.shape)
# Out:
# TF_IDF Shape:  (17368, 3000)

# %%
#df['fraudulent'] = df['fraudulent'].map({"real": 0, "fake":1})

df['fraudulent'].value_counts()
# Out:
# 0    16552
# 1      816
# Name: fraudulent, dtype: int64

# %% [markdown]
# # Labeling the Unlabeled Data

# %%
df_unlabeled = pd.read_csv("/content/drive/My Drive/FAKE JOB DETECTION/DATA SET/preprocessed_dataset_13-12-2023.csv")
print(f"Raw Data Shape: {df_unlabeled.shape}")
df_unlabeled.head()
# Out:
# Raw Data Shape: (34807, 15)
#         site                                        role  \
# 0  glassdoor                     data analyst data entry
# 1  glassdoor                    business systems analyst
# 2  glassdoor                                data analyst
# 3  glassdoor  data analysis charlotte corporate location
# 4  glassdoor                       data science graduate
#
#                     company_name      location  \
# 0                       juristat        remote
# 1  distributed solar development   new york ny
# 2                      haberfeld    lincoln ne
# 3                     genpak llc  charlotte nc
# 4     hewlett packard enterprise     spring tx
#
#                                      job_description  min_salary  max_salary  \
# 0  juristat building innovative suite products ne...     30000.0     35000.0
# 1  join azad technology partners business systems...    130000.0    160000.0
# 2  haberfeld align marketing products people sust...     54000.0     82000.0
# 3  data analyst collect customer requirements det...     52000.0     81000.0
# 4  data science graduate role designated edge mea...     57000.0    131000.0
#
#    ratings    job_level Search_Keywords Search_Location Job_Detail_Link  \
# 0      NaN  entry_level             NaN             NaN             NaN
# 1      NaN          NaN             NaN             NaN             NaN
# 2      NaN          NaN             NaN             NaN             NaN
# 3      NaN          NaN             NaN             NaN             NaN
# 4      NaN          NaN             NaN             NaN             NaN
#
#   Post_Time Current_Time job_type
# 0       NaN          NaN      NaN
# 1       NaN          NaN      NaN
# 2       NaN          NaN      NaN
# 3       NaN          NaN      NaN
# 4       NaN          NaN      NaN

# %%
df_unlabeled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34807 entries, 0 to 34806
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   site             34807 non-null  object
#  1   role             34807 non-null  object
#  2   company_name     34652 non-null  object
#  3   location         34478 non-null  object
#  4   job_description  32421 non-null  object
#  5   min_salary       14250 non-null  float64
#  6   max_salary       14250 non-null  float64
#  7   ratings          3878 non-null   float64
#  8   job_level        13186 non-null  object
#  9   Search_Keywords  1208 non-null   object
#  10  Search_Location  1208 non-null   object
#  11  Job_Detail_Link  1208 non-null   object
#  12  Post_Time        1208 non-null   object
#  13  Current_Time     1208 non-null   object
#  14  job_type         626 non-null    object
# dtypes: float64(3), object(12)
# memory usage: 4.0+ MB

# %%
df_unlabeled.describe(include = "all")
# Out:
#              site          role company_name location  \
# count       34807         34807        34652    34478
# unique          3         13519        13574     4974
# top     glassdoor  data analyst       tiktok   remote
# freq        21571          4176          222     1414
# mean          NaN           NaN          NaN      NaN
# std           NaN           NaN          NaN      NaN
# min           NaN           NaN          NaN      NaN
# 25%           NaN           NaN          NaN      NaN
# 50%           NaN           NaN          NaN      NaN
# 75%           NaN           NaN          NaN      NaN
# max           NaN           NaN          NaN      NaN
#
#                                           job_description    min_salary  \
# count                                               32421  1.425000e+04
# unique                                              28560           NaN
# top     aipowered robotic technology platform symbotic...           NaN
# freq                                                   49           NaN
# mean                                                  NaN  2.252753e+09
# std                                                   NaN  3.643616e+10
# min                                                   NaN  1.400000e+01
# 25%                                                   NaN  4.500000e+04
# 50%                                                   NaN  6.500000e+04
# 75%                                                   NaN  8.400000e+04
# max                                                   NaN  1.188475e+12
#
#           max_salary      ratings job_level Search_Keywords Search_Location  \
# count   1.425000e+04  3878.000000     13186            1208            1208
# unique           NaN          NaN         5               1               1
# top              NaN          NaN   Unknown  data scientist   united states
# freq             NaN          NaN      7282            1208            1208
# mean    2.333653e+09     3.990330       NaN             NaN             NaN
# std     3.691536e+10     0.451955       NaN             NaN             NaN
# min     1.600000e+01     1.000000       NaN             NaN             NaN
# 25%     6.075900e+04     3.800000       NaN             NaN             NaN
# 50%     9.200000e+04     4.000000       NaN             NaN             NaN
# 75%     1.180000e+05     4.200000       NaN             NaN             NaN
# max     1.140456e+12     5.000000       NaN             NaN             NaN
#
#                                           Job_Detail_Link  \
# count                                                1208
# unique                                                990
# top     https://www.indeed.com/rc/clk?jk=ab50cfa59689a...
# freq                                                    3
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                          Post_Time Current_Time       job_type
# count                         1208         1208            626
# unique                          89            1              9
# top     posted posted 30+ days ago   2023-11-14  not available
# freq                           233         1208            435
# mean                           NaN          NaN            NaN
# std                            NaN          NaN            NaN
# min                            NaN          NaN            NaN
# 25%                            NaN          NaN            NaN
# 50%                            NaN          NaN            NaN
# 75%                            NaN          NaN            NaN
# max                            NaN          NaN            NaN

# %%
df_unlabeled.describe(exclude="object")
# Out:
#          min_salary    max_salary      ratings
# count  1.425000e+04  1.425000e+04  3878.000000
# mean   2.252753e+09  2.333653e+09     3.990330
# std    3.643616e+10  3.691536e+10     0.451955
# min    1.400000e+01  1.600000e+01     1.000000
# 25%    4.500000e+04  6.075900e+04     3.800000
# 50%    6.500000e+04  9.200000e+04     4.000000
# 75%    8.400000e+04  1.180000e+05     4.200000
# max    1.188475e+12  1.140456e+12     5.000000

# %%
df_unlabeled.describe(exclude=np.number)
# Out:
#              site          role company_name location  \
# count       34807         34807        34652    34478
# unique          3         13519        13574     4974
# top     glassdoor  data analyst       tiktok   remote
# freq        21571          4176          222     1414
#
#                                           job_description job_level  \
# count                                               32421     13186
# unique                                              28560         5
# top     aipowered robotic technology platform symbotic...   Unknown
# freq                                                   49      7282
#
#        Search_Keywords Search_Location  \
# count             1208            1208
# unique               1               1
# top     data scientist   united states
# freq              1208            1208
#
#                                           Job_Detail_Link  \
# count                                                1208
# unique                                                990
# top     https://www.indeed.com/rc/clk?jk=ab50cfa59689a...
# freq                                                    3
#
#                          Post_Time Current_Time       job_type
# count                         1208         1208            626
# unique                          89            1              9
# top     posted posted 30+ days ago   2023-11-14  not available
# freq                           233         1208            435

# %% [markdown]
# There are many missing feature values, we will perform futhur checks

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:120%; text-align:left;padding: 0px;">Data Checks to perform </p>
#  - Check Missing values
#  - Check Duplicates
#  - Check data type
#  - Check the number of unique values of each column
#  - Check statistics of data set
#  - Check various categories present in the different categorical column
#
#  #### Missing values

# %%
df_unlabeled.isnull().sum()
# Out:
# site                   0
# role                   0
# company_name         155
# location             329
# job_description     2386
# min_salary         20557
# max_salary         20557
# ratings            30929
# job_level          21621
# Search_Keywords    33599
# Search_Location    33599
# Job_Detail_Link    33599
# Post_Time          33599
# Current_Time       33599
# job_type           34181
# dtype: int64

# %%
## Here we will check the percentage of nan values present in each feature
feature_na = [feature for feature in df_unlabeled.columns if df_unlabeled[feature].isnull().sum() > 0 ]

for feature in feature_na:
    print(feature, np.round(df_unlabeled[feature].isnull().mean() * 100,4), " % missing")
# Out:
# company_name 0.4453  % missing
# location 0.9452  % missing
# job_description 6.8549  % missing
# min_salary 59.06  % missing
# max_salary 59.06  % missing
# ratings 88.8586  % missing
# job_level 62.1168  % missing
# Search_Keywords 96.5294  % missing
# Search_Location 96.5294  % missing
# Job_Detail_Link 96.5294  % missing
# Post_Time 96.5294  % missing
# Current_Time 96.5294  % missing
# job_type 98.2015  % missing

# %%
# Null valuse more than 10%
columns_with_null_values_total = (df_unlabeled.isnull().sum() / len(df_unlabeled)) * 100
columns_with_null_values_percentage = columns_with_null_values_total[columns_with_null_values_total > 10].sort_values(ascending=False)

columns_with_null_values_percentage
# Out:
# job_type           98.201511
# Search_Keywords    96.529434
# Search_Location    96.529434
# Job_Detail_Link    96.529434
# Post_Time          96.529434
# Current_Time       96.529434
# ratings            88.858563
# job_level          62.116816
# min_salary         59.059959
# max_salary         59.059959
# dtype: float64

# %% [markdown]
# <b>observation:</b> There are many missing feature values. There 8 features with ~85% values are null and 2 features with ~65% null.
#
# The feature with 50% null values can be removed from the dataset

# %%
df_unlabeled.drop(columns_with_null_values_percentage.keys().tolist(),axis=1,inplace=True)

df_unlabeled.head()
# Out:
#         site                                        role  \
# 0  glassdoor                     data analyst data entry
# 1  glassdoor                    business systems analyst
# 2  glassdoor                                data analyst
# 3  glassdoor  data analysis charlotte corporate location
# 4  glassdoor                       data science graduate
#
#                     company_name      location  \
# 0                       juristat        remote
# 1  distributed solar development   new york ny
# 2                      haberfeld    lincoln ne
# 3                     genpak llc  charlotte nc
# 4     hewlett packard enterprise     spring tx
#
#                                      job_description
# 0  juristat building innovative suite products ne...
# 1  join azad technology partners business systems...
# 2  haberfeld align marketing products people sust...
# 3  data analyst collect customer requirements det...
# 4  data science graduate role designated edge mea...

# %%
df_unlabeled.columns
# Out:
# Index(['site', 'role', 'company_name', 'location', 'job_description'], dtype='object')

# %%
df_unlabeled.drop(columns=['site','company_name'],inplace = True)

# %%
df_unlabeled.head()
# Out:
#                                          role      location  \
# 0                     data analyst data entry        remote
# 1                    business systems analyst   new york ny
# 2                                data analyst    lincoln ne
# 3  data analysis charlotte corporate location  charlotte nc
# 4                       data science graduate     spring tx
#
#                                      job_description
# 0  juristat building innovative suite products ne...
# 1  join azad technology partners business systems...
# 2  haberfeld align marketing products people sust...
# 3  data analyst collect customer requirements det...
# 4  data science graduate role designated edge mea...

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:120%; text-align:left;padding: 0px;"> Duplicate Values Check </p>

# %%
df_unlabeled.duplicated().sum()
# Out:
# 2371

# %%
print("***** Duplicate check Feature wise *****\n")

# Check Job description duplications
print("job_description: ", df_unlabeled["job_description"].duplicated().sum())
# Out:
# ***** Duplicate check Feature wise *****
#
# job_description:  6246

# %% [markdown]
# There are duplicated records, this has to taken care during preprocessing stage

# %%
#Sorting data according to text in ascending order
sorted_data_unlabeled=df_unlabeled.sort_values('job_description', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')

sorted_data_unlabeled[sorted_data_unlabeled["job_description"].duplicated()]
# Out:
#                                                     role  \
# 24532                                     data scientist
# 24183                                     data scientist
# 24244                                     data scientist
# 25019                                     data scientist
# 23497                                     data scientist
# ...                                                  ...
# 19369                          statistician intermediate
# 19383    nlp natural language processing product manager
# 19385                  artificial intelligence developer
# 19396  ai machine learning algorithms architect resea...
# 19397                             statistician edison nj
#
#                            location  \
# 24532                    seattle wa
# 24183                los angeles ca
# 24244                    houston tx
# 25019               philadelphia pa
# 23497                     dallas tx
# ...                             ...
# 19369  thompson street ann arbor mi
# 19383                     austin tx
# 19385                 washington dc
# 19396                santa clara ca
# 19397                           NaN
#
#                                          job_description
# 24532  _dla piper equal opportunity employer qualifie...
# 24183  _dla piper equal opportunity employer qualifie...
# 24244  _dla piper equal opportunity employer qualifie...
# 25019  _dla piper equal opportunity employer qualifie...
# 23497  _dla piper equal opportunity employer qualifie...
# ...                                                  ...
# 19369                                                NaN
# 19383                                                NaN
# 19385                                                NaN
# 19396                                                NaN
# 19397                                                NaN
#
# [6246 rows x 3 columns]

# %%
df_unlabeled.shape
# Out:
# (34807, 3)

# %% [markdown]
# #### Check the Feature Uniqueness

# %%
for feature in df_unlabeled.columns:
    print('{}: Unique Count: {}\n {}\n'.format(feature, len(df_unlabeled[feature].unique()), df_unlabeled[feature].unique()))
# Out:
# role: Unique Count: 13519
#  ['data analyst data entry' 'business systems analyst' 'data analyst' ...
#  'exploitation analyst tssci w fs poly'
#  'russian lang analystactive tssci clearance required'
#  'programfinancial analyst']
#
# location: Unique Count: 4975
#  ['remote' 'new york ny' 'lincoln ne' ... 'montréal'
#  'base camp toronto canada' 'kitchener']
#
# job_description: Unique Count: 28561
#  ['juristat building innovative suite products need team create tools seeking highly motivated organized individual join data team data analyst team responsible acquiring analyzing complete accurate data available grow products inform business strategies particular team member responsible analyzing incoming legal documents realtime detect correct errors processing enter data source documents templates annotate legal documents provide feedback others improve proprietary artificial intelligence role remote workfromhome possess high attention detail strong work ethic job position responsibilities include collecting analyzing digital documents related data reviewing data documents errors entering correcting formatting data source documents working cooperatively juristat team members consistently meeting individual team performance objectives becoming familiar juristats tools systems order understand teamrelated internal systems processes procedures potential grow larger role based performance skills experience entrylevel position salary range kyear plus overtime required room potential growth leadership trainingdevelopment technical revenue positions learn working juristat visit career page dei page offer fully remote work environment flexible work times flexible pto multiple health insurance plan choices k companyfunded equipment several qualities make stand right person fill position particular extremely organized possess high attention detail strong work ethic trustworthy maintain confidentiality skilled typing using digital word processors microsoft word andor google documents well similar computer applications knowledgeable correct spelling grammar punctuation quickly adapt new processes procedures team grows processes rapidly improve excited learn current processes infrastructure willing provide creative suggestions improve workflow grow role juristat equalopportunity employer excited work people matter race color creed religion veteran status national origin ancestry sex sexual orientation gender identity expression age marital status pregnancy status mental physical disability actively work develop maintain fully inclusive workspaces recognize career gaps career changes personal hardship experiences workplace discrimination discourage spectacular candidates applying please hesitate apply wed love hear note fully remote position consider whose legal residence texas colorado missouri virginia maryland illinois correspondence related position come juristat hiring manager authorized recruiter protect scammers imitate company job listings read protect scams juristat believe key success building team selfmotivated curious people get things done dont care wear work look like prefer work remotely forever care unflinching drive best lawyer data scientist software developer walked startup event yes beginnings read like start joke bridging gap legal industry technology worlds built suite tools unlike market obtaining us patent springboard innovation process timeconsuming expensive aim remove much guesswork possible patent application process since law firms corporate legal teams trusted juristats data analytics workflow automation solutions juristat continue work towards bold vision future legal industry new product iteration one step closer realizing mission bring transparency predictability equity patent prosecution obsessed improvement products processes organization thrive small teams allow us fast flexible avoid bureaucracy slows growth driven opportunity passion creating change offer enjoy working safe welcoming inclusive environment agree follow code conduct additionally show team members value offering following remote position pressure ever come back office flexible personal leave policy competitive salary medical dental vision coverage k company match professional development funding fun flexible work environment juristat equalopportunity employer excited work people matter race color creed religion veteran status national  ...
#  'join azad technology partners business systems analyst support regional energy utility organization committed operability sustainability individual perform process controls systems analysis interfacing users support functional technical requirements development analysis tools techniques support development processes systems controls years plus consultant position high probability long term ongoing continued employment position hybrid vancouver wa onsite days weekly hourly pay rate range position depending related qualifications experience well composition selected compensation package show report'
#  'haberfeld align marketing products people sustained significant organization growth applying strategy consulting marketing training analytics like live core values integrity excellence collaboration curiosity joyinthejourney cherryontop employeeowned love celebrating reap benefits hard work cool want seeking dynamic individual join data team giving opportunity part company proud employee owned able answer yes dream sql logical operators love language get charge analyzing numbers finding correlation trends details help others excel enjoy pouring key statistics aid creation numeric analysis customer behavior modeling working methods predictive analytics exploratory data analysis spatial analysis cluster analysis grouping techniques something gets heart pumping enjoy thriving collaborative environment value lifework balance youll apply wizardry modeling customer behaviors evaluating account behaviors creating marketing recommendations processing analyzing customer data marketing creating numeric analysis consumer behaviors producing various reports including crosssell modeling segmentation retention modeling trending analytics youll need selfstarter mentality expert knowledge experience working transactsql ability create resolve complex sql queries knowledge net c javascript microsoft sql server ms product suite address iq match iq first logic favorable required knowledge ms excel ability problem solve desire learn associates bachelors degree computer science related field preferred show money haberfeld like brag benefits put together package make jaw drop heres sampling expect competitive base salary bonus potential responsible time rto paid pregnancyrelated leave paid bonding leave company holidays extra haberfeld holidays medical dental vision insurance pay health savings account hsa wellness screenings disability insurance group term life insurance voluntary life insurance option employee assistance eap employee stock ownership plan esop k flexible work schedule tuesday thursday inoffice days casual office attire healthjoy appwellable app employeeowner education recruiting bonus opportunity free parking summer early fridays onsite gym show less report'
#  ...
#  'brock solutions innovative engineering solutions professional services company specializing design build implementation realtime operational solutions broad based industrialmanufacturing transportationlogistics organizations worldwide interesting areas exploring include industrial automation machine learning iiot cyber security ai robotics technologies approximately employees globally brock solutions privately held employee owned organization years realtime operational solutions space offer working highly motivated developers involved entire cycle software engineering process employeeowned company profit sharing comprehensive benefits company events charitable initiatives diverse workplace bbqs lunch learns sports teams group fitness initiatives win team culture reasons employees love working brock brock solutions offers flexible work environment includes combination home office onsite options individuals balance work life end intent enable team work effectively collaboratively produce results matter brock solutions continues grow respond ongoing requirements major clients need add talent base outstanding professionals currently seeking software support developer join team experienced professionals located head office kitchener ontario work brock competitive compensation package profit sharing extended health benefits continuous career growth flexible working hours company events celebrations travel opportunities youll perform level technical support airport airline customers troubleshooting wide range issues areaffecting operation baggage handling systems assist level service technicians providing indepth troubleshooting technical support conduct root cause analysis defects identified production fix test deploy software patches maintain develop improve automated test deployment tools collaborate crossfunctional teams analyze document recommend improvements products internal processes qualifications required excellent communication skills verbal written strong troubleshooting skills experience objectoriented programming language required c preferred java c languages also acceptable proficiency sql knowledge databases knowledge flyway powershell azure devops javascriptis asset ability perform nightweekend work desired skills experience bachelors degree systems engineering software engineering computer science related fields preferred years experience coop considered graduated within last years please also submit soft copy transcript unofficial copy fine job information applicable new grads welcome apply graduated within last years please also submit soft copy transcript unofficial copy fine brock solutions strives create respectful accessible inclusive work environment upon individual request brock solutions endeavour remove barriers hiring process accommodate candidates disabilities please advised outside official applicant tracking system brock solutions never solicit personal information upfront send formal offer documentation writing first wait acceptance asking additional personal information'
#  'join urbanlogiq data empowers communities urbanlogiq developing platform revolutionizing government agencies leverage data enhance community life since inception weve forefront govtech industrys innovation growing rapidly making waves globally focus offering comprehensive cloudbased saas enterprise solutions built top data platform tailored public government agencies platform isnt data visualization analytics transforming governments understand manage utilize data optimize services ensuring theyre responsive efficient citizencentric ensuring best inclass measures around secure ethical data use mission make advanced data science software services universally accessible enabling governments big small forge stronger safer connected communities innovative software already choice government agencies canada us getting started joining us youre becoming part dynamic passionate team also shaping future communities datadriven innovation come part transformation urbanlogiq role urbanlogiq seeks datadriven solutions problems facing communities result large number data engineering challenges currently seeking bolster team aspiring data engineer software engineer working data team urbanlogiq role blend technical mastery storytelling data heart transforming communities evolve building robust elt extract load transform pipelines daytoday involves wrangling disparate types unique data government thirdparty sources turning coherent actionable narratives role navigate complexities diverse datasets different domains drawing meaningful patterns insights work critical youre processing data youre laying groundwork informed decisionmaking directly impacts communities role requires adaptability strong technical acumen passion making tangible difference technical expertise pivotal advancing mission develop robust unique data platform platform key storing analyzing worlds comprehensive datasets unlocking insights essential building better communities requirements bachelors masters degree computer science related field equivalent work experience software engineer years experience beyond software development excellent verbal written communication skills interpersonal skills ability communicate effectively diverse group people essential success role experience either python systems programming language like rust nice haves experience developing managing efficient pipelined operations preferably data also asset build pipelines experience developing deploying machine deep learning systems experience extracting data source files like excel spreadsheets pdfs data processing environment experience complex geospatial datasets youre passionate helping build innovative solutions make positive impact cities communities excited working fastpaced collaborative environment wed love hear'
#  'java developer full stack contract duration months must haves java development years spring framework springboot years restapis years sql sql years strong communication skills cicd experience years angular react years nice cloud experience former banking experience company top north american bank client aims stand peers differentiated brand anchored proven business model rooted desire give customers communities colleagues confidence thrive changing world client engages providing financial products services offer various financial products services telephone internet mobile banking services retail commercial banking services wealth management services wholesale banking segment provides capital markets investment banking corporate banking products investment needs companies governments institutions financial markets gttca']

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:120%; text-align:left;padding: 0px;"> Data preprocessing </p>
#
# <b>Handle Missing Values</b>

# %%
df_unlabeled.isnull().sum()
# Out:
# role                  0
# location            329
# job_description    2386
# dtype: int64

# %%
# Fill na values with missing

for feature in df_unlabeled.columns:
  if(df_unlabeled[feature].isnull().sum()>0):
    df_unlabeled[feature].fillna("missing", inplace=True)

df_unlabeled.isnull().sum()
# Out:
# role               0
# location           0
# job_description    0
# dtype: int64

# %% [markdown]
# <b>Deduplication of data</b>

# %%
df_unlabeled.duplicated().sum()
# Out:
# 2371

# %%
df_unlabeled.drop_duplicates(keep="first", inplace= True)
print("Shape: ", df_unlabeled.shape)

df_unlabeled.duplicated().sum()
# Out:
# Shape:  (32436, 3)
# 0

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:120%; text-align:left;padding: 0px;"> Exploratory Data Analysis </p>
#
# #### Description: Analyze the count of Charecters, Words, and Sentences in each segment

# %%
# No. of charecters in Job Description
df_unlabeled['desc_num_char'] = df_unlabeled['job_description'].apply(len)

# No. of of words in Job Description
df_unlabeled['desc_num_words'] = df_unlabeled['job_description'].apply(lambda x:len(nltk.word_tokenize(x)))

# No. of of sentences in Job Description
df_unlabeled['desc_num_sent'] = df_unlabeled['job_description'].apply(lambda x:len(nltk.sent_tokenize(x)))

df_unlabeled.head()
# Out:
#                                          role      location  \
# 0                     data analyst data entry        remote
# 1                    business systems analyst   new york ny
# 2                                data analyst    lincoln ne
# 3  data analysis charlotte corporate location  charlotte nc
# 4                       data science graduate     spring tx
#
#                                      job_description  desc_num_char  \
# 0  juristat building innovative suite products ne...           4309
# 1  join azad technology partners business systems...            603
# 2  haberfeld align marketing products people sust...           2190
# 3  data analyst collect customer requirements det...            943
# 4  data science graduate role designated edge mea...           5391
#
#    desc_num_words  desc_num_sent
# 0             542              1
# 1              70              1
# 2             276              1
# 3             119              1
# 4             675              1

# %%
df_unlabeled.describe(include=np.number)
# Out:
#        desc_num_char  desc_num_words  desc_num_sent
# count   32436.000000    32436.000000        32436.0
# mean     2520.224812      296.595912            1.0
# std      2076.809849      242.021956            0.0
# min         1.000000        1.000000            1.0
# 25%       725.000000       88.000000            1.0
# 50%      2272.000000      268.000000            1.0
# 75%      3734.000000      439.000000            1.0
# max     31300.000000     3753.000000            1.0

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#007fd4; font-size:120%; text-align:left;padding: 0px;"> Text preprocessing </p>
#
# Now that we have finished deduplication our data requires some preprocessing before we go on further with analysis and making the prediction model.
#
# Hence in the Preprocessing phase we do the following in the order below:-
#
# 1. Begin by removing the html tags
# 2. Remove any punctuations or limited set of special characters like , or . or # etc.
# 3. Check if the word is made up of english letters and is not alpha-numeric
# 4. Check to see if the length of the word is greater than 2 (as it was researched that there is no adjective in 2-letters)
# 5. Convert the word to lowercase
# 6. Remove Stopwords
# 7. Finally Snowball Stemming the word (it was obsereved to be better than Porter Stemming)<br>
#
# After which we collect the words used to describe positive and negative type

# %%
# https://gist.github.com/sebleier/554280
# we are removing the words from the stop words list: 'no', 'nor', 'not'
# <br /><br /> ==> after the above steps, we are getting "br br"
# we are including them into stop words list
# instead of <br /> if we have <br/> these tags would have revmoved in the 1st step

stopWords= set(['br', 'the', 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've",\
            "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', \
            'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their',\
            'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', \
            'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', \
            'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', \
            'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after',\
            'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further',\
            'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',\
            'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', \
            's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', \
            've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn',\
            "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn',\
            "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", \
            'won', "won't", 'wouldn', "wouldn't"])

# %%
def decontracted(phrase):
    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

def preprocess(corpus):
    preprocessed = []
    for sentance in tqdm(corpus):
        #sentance = re.sub(r"http+", "", sentance)
        sentance = re.sub(r"http\S+", "", sentance)
        sentance = BeautifulSoup(sentance, 'lxml').get_text()
        sentance = decontracted(sentance)
        sentance = re.sub("\S*\d\S*", "", sentance).strip()
        sentance = re.sub('[^A-Za-z]+', ' ', sentance)
        #sentance = ' '.join(e.lower() for e in sentance.split() if e.lower() not in stopWords)
        #sentence = ' '.join(token.lower() for token in nltk.word_tokenize(sentance) if token.lower() not in stopwords.words('english'))
        #preprocessed.append(sentance.strip())
        preprocessed.append(' '.join(token.lower() for token in nltk.word_tokenize(sentance) if token.lower() not in stopwords.words('english')))

    return preprocessed

# %%
df_unlabeled.sample(5)
# Out:
#                                      role        location  \
# 22977         functional business analyst  san antonio tx
# 9174                       data scientist    johannesburg
# 30666             risk compliance analyst          sydney
# 4629                         data analyst         arizona
# 16414  big data analyst onsite houston tx      houston tx
#
#                                          job_description  desc_num_char  \
# 22977  description functional business analyst micros...           7774
# 9174   gauteng jhb southern suburbs r r monthly cost ...            863
# 30666  role support head legal risk compliance suppor...           1561
# 4629   cdc foundation helps centers disease control p...           4686
# 16414                                            missing              7
#
#        desc_num_words  desc_num_sent
# 22977             886              1
# 9174              101              1
# 30666             177              1
# 4629              558              1
# 16414               1              1

# %%
df_unlabeled.dtypes
# Out:
# role               object
# location           object
# job_description    object
# desc_num_char       int64
# desc_num_words      int64
# desc_num_sent       int64
# dtype: object

# %%
# %%time

df_unlabeled["desc_transformed"] = preprocess(df_unlabeled['job_description'].values)
#df["site_transformed"] = preprocess(df['site'].values)
#df["role_transformed"] = preprocess(df['role'].values)
#df["comp_transformed"] = preprocess(df['company_name'].values)
#df["loc_transformed"] = preprocess(df['location'].values)


df_unlabeled["desc_transformed"][:5]
# Out:
# 100%|██████████| 32436/32436 [12:54<00:00, 41.88it/s]
# CPU times: user 11min 3s, sys: 1min 38s, total: 12min 42s
# Wall time: 12min 54s
# 0    juristat building innovative suite products ne...
# 1    join azad technology partners business systems...
# 2    haberfeld align marketing products people sust...
# 3    data analyst collect customer requirements det...
# 4    data science graduate role designated edge mea...
# Name: desc_transformed, dtype: object

# %%
df_unlabeled.head()
# Out:
#                                          role      location  \
# 0                     data analyst data entry        remote
# 1                    business systems analyst   new york ny
# 2                                data analyst    lincoln ne
# 3  data analysis charlotte corporate location  charlotte nc
# 4                       data science graduate     spring tx
#
#                                      job_description  desc_num_char  \
# 0  juristat building innovative suite products ne...           4309
# 1  join azad technology partners business systems...            603
# 2  haberfeld align marketing products people sust...           2190
# 3  data analyst collect customer requirements det...            943
# 4  data science graduate role designated edge mea...           5391
#
#    desc_num_words  desc_num_sent  \
# 0             542              1
# 1              70              1
# 2             276              1
# 3             119              1
# 4             675              1
#
#                                     desc_transformed
# 0  juristat building innovative suite products ne...
# 1  join azad technology partners business systems...
# 2  haberfeld align marketing products people sust...
# 3  data analyst collect customer requirements det...
# 4  data science graduate role designated edge mea...

# %%
# %%time
#OPTIMIZED
# Function to calculate sentiment scores for a single row
def calculate_sentiment_scores(row):
    tokens = word_tokenize(row['desc_transformed'])
    positive_score = np.sum(np.isin(tokens, list(positive_words)))
    negative_score = np.sum(np.isin(tokens, list(negative_words)))
    return positive_score, negative_score

# Convert Pandas DataFrame to a list of dictionaries
data_for_parallel_unlabeled = df_unlabeled[['desc_transformed']].to_dict('records')

# Calculate sentiment scores using parallel processing
with ProcessPoolExecutor() as executor:
    sentiment_scores_unlabeled = list(executor.map(calculate_sentiment_scores, data_for_parallel_unlabeled))

# Assign sentiment scores to the DataFrame
df_unlabeled[['positive_score', 'negative_score']] = np.array(sentiment_scores_unlabeled)

# Display the DataFrame with new sentiment score columns
print(df_unlabeled[['desc_transformed', 'positive_score', 'negative_score']])
# Out:
#                                         desc_transformed  positive_score  \
# 0      juristat building innovative suite products ne...              60
# 1      join azad technology partners business systems...               5
# 2      haberfeld align marketing products people sust...              27
# 3      data analyst collect customer requirements det...               4
# 4      data science graduate role designated edge mea...              64
# ...                                                  ...             ...
# 34802  pala interactiveis fullservice real money soci...              16
# 34803  date posted hiring organization rose internati...              32
# 34804  brock solutions innovative engineering solutio...              36
# 34805  join urbanlogiq data empowers communities urba...              46
# 34806  java developer full stack contract duration mo...               6
#
#        negative_score
# 0                   9
# 1                   0
# 2                   3
# 3                   4
# 4                   8
# ...               ...
# 34802              10
# 34803              10
# 34804               2
# 34805               4
# 34806               1
#
# [32436 rows x 3 columns]
# CPU times: user 11 s, sys: 1.83 s, total: 12.9 s
# Wall time: 1min 55s

# %%
df_unlabeled.head()
# Out:
#                                          role      location  \
# 0                     data analyst data entry        remote
# 1                    business systems analyst   new york ny
# 2                                data analyst    lincoln ne
# 3  data analysis charlotte corporate location  charlotte nc
# 4                       data science graduate     spring tx
#
#                                      job_description  desc_num_char  \
# 0  juristat building innovative suite products ne...           4309
# 1  join azad technology partners business systems...            603
# 2  haberfeld align marketing products people sust...           2190
# 3  data analyst collect customer requirements det...            943
# 4  data science graduate role designated edge mea...           5391
#
#    desc_num_words  desc_num_sent  \
# 0             542              1
# 1              70              1
# 2             276              1
# 3             119              1
# 4             675              1
#
#                                     desc_transformed  positive_score  \
# 0  juristat building innovative suite products ne...              60
# 1  join azad technology partners business systems...               5
# 2  haberfeld align marketing products people sust...              27
# 3  data analyst collect customer requirements det...               4
# 4  data science graduate role designated edge mea...              64
#
#    negative_score
# 0               9
# 1               0
# 2               3
# 3               4
# 4               8

# %%
df_unlabeled_score = df_unlabeled.copy()

# %%
df_unlabeled_score.to_csv("/content/drive/My Drive/FAKE JOB DETECTION/DATA SET/Processed_data_score.csv", index=False)

# %%
df_unlabeled = pd.read_csv("/content/drive/My Drive/FAKE JOB DETECTION/DATA SET/Processed_data_score.csv")

# %%
df_unlabeled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32436 entries, 0 to 32435
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   role              32436 non-null  object
#  1   location          32436 non-null  object
#  2   job_description   32436 non-null  object
#  3   desc_num_char     32436 non-null  int64
#  4   desc_num_words    32436 non-null  int64
#  5   desc_num_sent     32436 non-null  int64
#  6   desc_transformed  32435 non-null  object
#  7   positive_score    32436 non-null  int64
#  8   negative_score    32436 non-null  int64
# dtypes: int64(5), object(4)
# memory usage: 2.2+ MB

# %%
# Fill missing value in 'desc_transformed' with an empty string
df_unlabeled['desc_transformed'].fillna('', inplace=True)

# %%
# Load the unlabeled data
# Assuming df_unlabeled has columns: 'desc_transformed', 'positive_score', 'negative_score', 'desc_num_char', 'desc_num_words', 'desc_num_sent'
# If needed, fill any missing values in df_unlabeled
df_unlabeled = df_unlabeled.fillna('')

# Preprocess the text data
X_text_unlabeled = df_unlabeled['desc_transformed']
X_text_unlabeled_tfidf = tfidf_vectorizer.transform(X_text_unlabeled)

# Combine text TF-IDF vectors with numeric features for unlabeled data
X_unlabeled_combined = pd.concat([
    df_unlabeled[['positive_score', 'negative_score', 'desc_num_char', 'desc_num_words', 'desc_num_sent']].reset_index(drop=True),
    pd.DataFrame(X_text_unlabeled_tfidf.toarray())
], axis=1)

# Standardize numeric features
X_unlabeled_combined.iloc[:, :5] = scaler.transform(X_unlabeled_combined.iloc[:, :5])

# Apply Min-Max scaling to numeric features
X_unlabeled_combined[numeric_columns] = min_max_scaler.transform(X_unlabeled_combined[numeric_columns])

# Convert feature names to strings
X_unlabeled_combined.columns = X_unlabeled_combined.columns.astype(str)

# Make predictions on the unlabeled data
predictions_unlabeled = best_model.predict(X_unlabeled_combined)

# Add predictions to the unlabeled DataFrame
df_unlabeled['predicted_label'] = predictions_unlabeled

# Display the DataFrame with predicted labels
print(df_unlabeled[['desc_transformed', 'positive_score', 'negative_score', 'desc_num_char', 'desc_num_words', 'desc_num_sent', 'predicted_label']])
# Out:
#                                         desc_transformed  positive_score  \
# 0      juristat building innovative suite products ne...              60
# 1      join azad technology partners business systems...               5
# 2      haberfeld align marketing products people sust...              27
# 3      data analyst collect customer requirements det...               4
# 4      data science graduate role designated edge mea...              64
# ...                                                  ...             ...
# 32431  pala interactiveis fullservice real money soci...              16
# 32432  date posted hiring organization rose internati...              32
# 32433  brock solutions innovative engineering solutio...              36
# 32434  join urbanlogiq data empowers communities urba...              46
# 32435  java developer full stack contract duration mo...               6
#
#        negative_score  desc_num_char  desc_num_words  desc_num_sent  \
# 0                   9           4309             542              1
# 1                   0            603              70              1
# 2                   3           2190             276              1
# 3                   4            943             119              1
# 4                   8           5391             675              1
# ...               ...            ...             ...            ...
# 32431              10           2243             285              1
# 32432              10           3929             476              1
# 32433               2           3051             356              1
# 32434               4           2795             329              1
# 32435               1            831             103              1
#
#        predicted_label
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 32431                0
# 32432                0
# 32433                0
# 32434                0
# 32435                0
#
# [32436 rows x 7 columns]

# %%
df_unlabeled.head()
# Out:
#                                          role      location  \
# 0                     data analyst data entry        remote
# 1                    business systems analyst   new york ny
# 2                                data analyst    lincoln ne
# 3  data analysis charlotte corporate location  charlotte nc
# 4                       data science graduate     spring tx
#
#                                      job_description  desc_num_char  \
# 0  juristat building innovative suite products ne...           4309
# 1  join azad technology partners business systems...            603
# 2  haberfeld align marketing products people sust...           2190
# 3  data analyst collect customer requirements det...            943
# 4  data science graduate role designated edge mea...           5391
#
#    desc_num_words  desc_num_sent  \
# 0             542              1
# 1              70              1
# 2             276              1
# 3             119              1
# 4             675              1
#
#                                     desc_transformed  positive_score  \
# 0  juristat building innovative suite products ne...              60
# 1  join azad technology partners business systems...               5
# 2  haberfeld align marketing products people sust...              27
# 3  data analyst collect customer requirements det...               4
# 4  data science graduate role designated edge mea...              64
#
#    negative_score  predicted_label
# 0               9                0
# 1               0                0
# 2               3                0
# 3               4                0
# 4               8                0

# %%
df_unlabeled.to_csv("/content/drive/My Drive/FAKE JOB DETECTION/DATA SET/Processed_data_labelled.csv", index=False)

# %%
df_unlabeled["predicted_label"].value_counts()
# Out:
# 0    30569
# 1     1867
# Name: predicted_label, dtype: int64
